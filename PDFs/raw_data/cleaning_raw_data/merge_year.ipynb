# %%
# this notebook merges all the years of aligned raw data from calfire

# %%
import pandas as pd

# %%
df1 = pd.read_csv('./2016_fire_cause_by_county.csv')

# %%
df2 = pd.read_csv('./2016_fire_size_by_county.csv')

# %%
df3 = pd.merge(df1, df2, how = 'outer', on = 'county')

# %%
df3.head()
# Out:
#       county  Arson  Campfire  Debris Burning  Elec. Power  Equip. Use  Ltng.  \
# 0    Alameda      0         0               0            8           4      0
# 1     Alpine      0         0               0            0           0      0
# 2     Amador      2         0              17            6           7      1
# 3      Butte      0         0               0            0           0      0
# 4  Calaveras      1         3              22            9          14      0
#
#    Misc.  P-W-F  Railroad  ...  region_x  .25 acres or <  .26-9.99 acres  \
# 0      4      0         0  ...     north              10              20
# 1      0      0         0  ...       NaN               0               0
# 2      7      0         0  ...     north              29              21
# 3      0      0         0  ...     north               0               0
# 4     12      2         0  ...     south              54              28
#
# ...

# %%
df4 = pd.read_csv('./2016_Redbook_AcresByCause_ByCounty_Edit.csv')

# %%
df5 = pd.merge(df3, df4, how = 'outer', on = 'county')
df5.head()
# Out:
#       county  Arson_x  Campfire_x  Debris Burning_x  Elec. Power_x  \
# 0    Alameda        0           0                 0              8
# 1     Alpine        0           0                 0              0
# 2     Amador        2           0                17              6
# 3      Butte        0           0                 0              0
# 4  Calaveras        1           3                22              9
#
#    Equip. Use_x  Ltng._x  Misc._x  P-W-F_x  Railroad_x  ...  Equip. Use_y  \
# 0             4        0        4        0           0  ...          20.0
# 1             0        0        0        0           0  ...           0.0
# 2             7        1        7        0           0  ...          41.0
# 3             0        0        0        0           0  ...           0.0
# 4            14        0       12        2           0  ...         540.0
#
#    Ltng._y  Misc._y  P-W-F_y Railroad_y  Smoking_y  Undet._y  Vehicle_y  Year  \
# ...

# %%
df6 = pd.read_csv('./2016_Redbook_AcresByVegType_ByCounty.csv')

# %%
df7 = pd.merge(df5, df6, how = 'outer', on = 'county')
df7.head()
# Out:
#       county  Arson_x  Campfire_x  Debris Burning_x  Elec. Power_x  \
# 0    Alameda        0           0                 0              8
# 1     Alpine        0           0                 0              0
# 2     Amador        2           0                17              6
# 3      Butte        0           0                 0              0
# 4  Calaveras        1           3                22              9
#
#    Equip. Use_x  Ltng._x  Misc._x  P-W-F_x  Railroad_x  ...  Vehicle_y  Year  \
# 0             4        0        4        0           0  ...         40  2016
# 1             0        0        0        0           0  ...          0  2016
# 2             7        1        7        0           0  ...         48  2016
# 3             0        0        0        0           0  ...          0  2016
# 4            14        0       12        2           0  ...        456  2016
#
#    Region  Brush   Grass  Timber  Woodland  Other    year  region
# ...

# %%
df8 = pd.read_csv('./2016_Redbook_DollarsByCause_ByCounty.csv')

# %%
df9 = pd.merge(df7, df8, how = 'outer', on = 'county')
df9.head()
# Out:
#       county  Arson_x  Campfire_x  Debris Burning_x  Elec. Power_x  \
# 0    Alameda        0           0                 0              8
# 1     Alpine        0           0                 0              0
# 2     Amador        2           0                17              6
# 3      Butte        0           0                 0              0
# 4  Calaveras        1           3                22              9
#
#    Equip. Use_x  Ltng._x  Misc._x  P-W-F_x  Railroad_x  ...  Equip. Use  \
# 0             4        0        4        0           0  ...     $1,200
# 1             0        0        0        0           0  ...         $0
# 2             7        1        7        0           0  ...       $700
# 3             0        0        0        0           0  ...         $0
# 4            14        0       12        2           0  ...   $286,300
#
#    Ltng.      Misc.  P-W-F Railroad  Smoking    Undet.   Vehicle  year   \
# ...

# %%
df10 = pd.read_csv('./2016_Redbook_DollarDamage_Size.csv')

# %%
df11 = pd.merge(df9, df10, how = 'outer', on = 'county')
df11.head()
# Out:
#       county  Arson_x  Campfire_x  Debris Burning_x  Elec. Power_x  \
# 0    Alameda        0           0                 0              8
# 1     Alpine        0           0                 0              0
# 2     Amador        2           0                17              6
# 3      Butte        0           0                 0              0
# 4  Calaveras        1           3                22              9
#
#    Equip. Use_x  Ltng._x  Misc._x  P-W-F_x  Railroad_x  ...      region   \
# 0             4        0        4        0           0  ...  unspecified
# 1             0        0        0        0           0  ...  unspecified
# 2             7        1        7        0           0  ...  unspecified
# 3             0        0        0        0           0  ...  unspecified
# 4            14        0       12        2           0  ...  unspecified
#
#    .25 acres or <_y  .26-9.99 acres_y  10-99 acres_y 100-299 acres_y  \
# ...

# %%
df11.columns = [col.lower().replace(' ', '_') for col in df11.columns]

# %%
df11.head()
# Out:
#       county  arson_x  campfire_x  debris_burning_x  elec._power_x  \
# 0    Alameda        0           0                 0              8
# 1     Alpine        0           0                 0              0
# 2     Amador        2           0                17              6
# 3      Butte        0           0                 0              0
# 4  Calaveras        1           3                22              9
#
#    equip._use_x  ltng._x  misc._x  p-w-f_x  railroad_x  ...      region_  \
# 0             4        0        4        0           0  ...  unspecified
# 1             0        0        0        0           0  ...  unspecified
# 2             7        1        7        0           0  ...  unspecified
# 3             0        0        0        0           0  ...  unspecified
# 4            14        0       12        2           0  ...  unspecified
#
#    .25_acres_or_<_y  .26-9.99_acres_y  10-99_acres_y 100-299_acres_y  \
# ...

# %%
df11.to_csv(f'./2016_wildfire_statistics.csv', index = False)
